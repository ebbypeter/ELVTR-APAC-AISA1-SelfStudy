# %% [markdown]
# # Lesson 04 - Self Study
#
# Create 3 prompt variations, compare results.

# %% [markdown]
# ## Load Environment Variables
# All the environment variables, APIS keys etc are loaded in the `.env` file. Load it into memory.

# %%
import os
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()

print("ℹ️  Loaded environment variables from .env file")
# Out:
# ℹ️  Loaded environment variables from .env file

# %% [markdown]
# ## Initialize Wrappers
#
# Initialize the LLM Wrappers / Agents

# %%
# Imports
from langchain_openai import ChatOpenAI

# OpenAI GPT-4o Client
agent_openai_gpt4o = ChatOpenAI(
    name="OpenAI GPT-4o",
    model="gpt-4o",
    temperature=0.7,
    api_key=os.getenv('OPENAI_API_KEY'),
    organization=os.getenv('OPENAI_ORG_ID') if os.getenv('OPENAI_ORG_ID') else None
) 
print("ℹ️  OpenAI client initialized successfully with GPT-4o mode")
# Out:
# ℹ️  OpenAI client initialized successfully with GPT-4o mode

# %% [markdown]
# ## TCREI Framework

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# TCREI Prompt
tcrei_prompt = """
**Task**
Explain quantum mechanics basics to a complete beginner with no prior knowledge. 
Use simple analogies, no equations. 
4 short sections with headings.

**Context** 
Subject: Quantum Mechanics.
Audience: Complete beginner with no prior knowledge. 
Goal: 5-minute intuition for quantum "weirdness".

**Reference**
Style: excited, conversational tone. 
Cover: what "quantum" means, wave-particle duality, uncertainty principle, superposition.

**Examples**
Explain concepts like:
- What “quantum” means in everyday terms
- Particles vs waves (wave-particle duality)
- Uncertainty (Heisenberg's idea, in plain language)
- Superposition and measurement
Use short sections with headings, simple analogies (coins, dice, light), and no formulas.

**Instructions**
End with 3-bullet recap. Bold key terms. One analogy per concept. Max 500 words total.
"""

prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a world-class physics educator that explains complex concepts simply."),
    ("human", tcrei_prompt)
])

# Chain and Invoke
chain = prompt | agent_openai_gpt4o | StrOutputParser()
response = chain.invoke({})
 
# Response Output
print("🔷  Quantum Mechanics Overview (TECRI prompt):")
print("=" * 60)
print(response)

print("✅  TCREI prompt processed successfully with GPT-4o model")
# Out:
# Quantum Mechanics Overview (TECRI prompt):
# ============================================================
# ### What Does "Quantum" Mean?
#
# Imagine you’re trying to count the grains of sugar in a teaspoon. Each grain is tiny, right? Well, in the world of quantum mechanics, we're dealing with the tiniest building blocks of the universe—smaller than even the smallest sugar grain. The word **"quantum"** comes from the Latin word for "amount," and it’s all about the smallest possible pieces of things. Just like sugar grains make up your teaspoon, **quantum** pieces like electrons and photons make up everything around us. The catch? These quantum pieces behave in ways that are nothing like our everyday experiences!
#
# ### Particles vs. Waves: The Curious Case of Light
#
# Picture a beach ball that can sometimes behave like a wave in the ocean. That's the best way to think about **wave-particle duality**. For a long time, people thought light was just a wave, like ripples on a pond. But then, they discovered light could also act like tiny particles, called photons, hitting a surface like sand grains. It's like having a magic beach ball that can bounce and also float away like a wave. This dual nature is a signature of the quantum world, where things can be both particles and waves depending on how you look at them.
#
# ### The Uncertainty Principle: Fuzzy Dice
#
# Imagine you have a pair of fuzzy dice hanging in your car, swinging as you drive. If you try to grab one to see exactly where it is, you stop it from swinging, but you can’t tell how fast it was moving. This is similar to Heisenberg’s **Uncertainty Principle**. In quantum mechanics, the more precisely you know where a tiny particle is, the less you know about how fast it's going, and vice versa. It's like the dice can never be perfectly still or perfectly measured—there's always a little fuzziness!
#
# ### Superposition: The Coin That’s Both Heads and Tails
#
# Think of a spinning coin in mid-air. While it spins, is it heads or tails? In the quantum world, particles can exist in multiple states at once, much like the coin is both heads and tails until it lands. This is known as **superposition**. It’s only when you look at the coin (or measure the quantum state) that it "chooses" one outcome. This concept is like having a coin that’s both heads and tails until you catch it in your hand.
#
# ### Recap
#
# - **Quantum** refers to the smallest building blocks of everything around us, behaving in unfamiliar ways.
# - **Wave-particle duality** shows that quantum objects like light can act as both particles and waves.
# - The **Uncertainty Principle** tells us there’s a fundamental limit to how precisely we can know a particle's position and speed at the same time.
# - **Superposition** describes particles existing in multiple states until they’re observed, like a spinning coin that’s both heads and tails.
#
# Welcome to the wonderfully weird world of quantum mechanics!
# ✅  TCREI prompt processed successfully with GPT-4o model

# %% [markdown]
# # Zero-Shot / One-Shot / Multi-Shot

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

base_prompt = ChatPromptTemplate.from_messages([
    ("system", "You are an expert educator that explains concepts clearly and concisely."),
    ("human", """
     Explain quantum mechanics basics to a complete beginner with no prior knowledge. Use simple analogies, no equations.
     Use simple analogies, no equations.
     4 short sections with headings.
     
     Subject: Quantum Mechanics
     Audience: Complete beginner with no prior knowledge. 
     
     {examples_block}
     """)
])
 
chain = base_prompt | agent_openai_gpt4o | StrOutputParser()

# Zero Shot Example
zero_shot_example = ""
print("🔷  Zero Shot Prompt Response:")
print("=" * 60)

cot_response = chain.invoke({
    "examples_block": zero_shot_example.strip()
})
print(cot_response)


# One Shot Example
one_shot_example = """
## Topic: Electricity
**What electricity is:**
Electricity is the flow of tiny invisible particles called electrons through wires, like water flowing through pipes. 
When you flip a switch, you let electrons move and power your lights.
**How it works:**
Electrons carry energy. A battery pushes them along, like squeezing toothpaste from a tube. 
The faster they flow, the brighter your bulb glows.
"""
print("\n🔷  One Shot Prompt Response:")
print("=" * 60)
response_one_shot = chain.invoke({
    "examples_block": one_shot_example.strip()
})
print(response_one_shot)

# Multi Shot Example
multi_shot_example = """
## Topic: Gravity
**What gravity does:**
Gravity pulls things toward each other, like Earth grabbing you so you don't float away. 
Drop a ball—it falls because Earth pulls it down.

## Topic: Atoms
**What atoms are:**
Atoms are tiny building blocks of everything—your phone, water, air. 
Each has a center (nucleus) with electrons buzzing around like bees around a hive.

## Topic: Light
**What light is:**
Light can behave like tiny bullets of energy and also like ripples in a pond. 
When it passes through a prism, it spreads into colors because the wave part bends differently.
"""
print("\n🔷  Multi Shot Prompt Response:")
print("=" * 60)
response_multi_shot = chain.invoke({
    "examples_block": multi_shot_example.strip()
})
print(response_multi_shot)

print("\n\n✅  Zero-Shot, One-Shot, Multi-Shot prompting processed successfully with GPT-4o model")
# Out:
# 🔷  Zero Shot Prompt Response:
# ============================================================
# **1. The Strange World of the Tiny**
#
# Imagine the world as a giant playground filled with different-sized toys. In our everyday world, we play with big toys like balls and cars, and they behave predictably: if you push a ball, it rolls away. But in the quantum playground, the toys are incredibly tiny, like marbles or grains of sand, and they behave in ways that seem strange and unpredictable. Quantum mechanics is the set of rules that explains how these tiny toys behave. It's a world where things can be in two places at once or change just by being watched!
#
# **2. Particles and Waves: The Dual Nature**
#
# Think of light as a magical creature that can change its form. Sometimes it behaves like a stream of tiny bullets (particles), and other times it moves like a wave in the ocean. In the quantum world, tiny objects like electrons also have this dual personality. It’s like they’re superheroes with two identities: sometimes acting as solid particles, other times as waves. This dual nature is called wave-particle duality, and it’s one of the mind-bending concepts of quantum mechanics.
#
# **3. The Uncertainty Principle: A Blurry Picture**
#
# Imagine trying to take a picture of a speeding car with an old camera. The picture comes out blurry, and you can't tell exactly where the car is or how fast it’s going. This is similar to the quantum uncertainty principle. In the tiny world of quantum mechanics, the more precisely we try to measure one property of a particle (like its position), the less precisely we can know another property (like its speed). It’s as if the universe has a built-in fuzziness when it comes to these tiny objects.
#
# **4. Quantum Entanglement: The Spooky Connection**
#
# Picture two magical twins who can talk to each other instantly, no matter how far apart they are. If one twin tells a joke, the other laughs at the exact same moment, even if they’re on opposite sides of the planet. Quantum entanglement is a bit like that magical connection. When two particles become entangled, they remain connected so that the state of one instantly influences the state of the other, no matter the distance. This "spooky action at a distance," as Einstein called it, is one of the most mysterious and fascinating aspects of quantum mechanics.
#
# 🔷  One Shot Prompt Response:
# ============================================================
# ## Topic: Quantum Mechanics
#
# **What Quantum Mechanics Is:**
# Quantum mechanics is a branch of science that explores the behavior of the tiniest bits of matter, like atoms and particles. Imagine trying to understand a world where things can be in two places at once, or where simply observing something can change its state. It's like a magical realm where the rules are different from our everyday experiences.
#
# **How Particles Behave:**
# In the everyday world, things are solid and predictable, like a rock sitting on the ground. But in the quantum world, particles act more like waves in the ocean, constantly moving and changing. They don't have a definite position until you look at them, similar to how a wave can spread out across the beach but only forms a crest when it hits a rock.
#
# **The Role of Uncertainty:**
# One of the key ideas in quantum mechanics is uncertainty. Think of it like trying to catch a ball in the dark. You might know the direction it's coming from, but you can't be sure exactly where it will land. Similarly, in the quantum world, we can predict the likelihood of where a particle might be, but not its exact spot until it's observed.
#
# **Entanglement: The Strange Connection:**
# Quantum entanglement is like a mysterious bond between two particles, even if they're far apart. Imagine having twin siblings who can feel each other's moods no matter the distance. If you tickle one, the other laughs, even if they're miles away. In quantum mechanics, this connection means what happens to one particle instantly affects the other, defying the usual rules of space and time.
#
# 🔷  Multi Shot Prompt Response:
# ============================================================
# ## Topic: Quantum Mechanics
# **What quantum mechanics is:**
# Quantum mechanics is like the rulebook for the tiny world of atoms and particles, where things work differently from our everyday experiences. Imagine a funhouse where reflections and movements defy normal expectations—quantum mechanics is the set of rules that explain these unusual behaviors.
#
# ## Topic: Uncertainty
# **What uncertainty means:**
# In the quantum world, it's like trying to catch a butterfly in a dark room. You can either know where it is or how fast it's flying, but not both at the same time. This principle, called uncertainty, means we can't predict everything precisely, only guess with probabilities.
#
# ## Topic: Superposition
# **What superposition is:**
# Think of a spinning coin in the air. Until it lands, it's not just heads or tails—it's both, sort of. In the quantum realm, particles can be in multiple states at once, like being in two places at the same time, until we check on them.
#
# ## Topic: Entanglement
# **What entanglement is:**
# Imagine having two magical dice that, no matter how far apart, always land on the same number when you roll them. In quantum mechanics, entangled particles behave in this connected way, instantly affecting each other, even across great distances.
# ✅  Zero-Shot, One-Shot, Multi-Shot prompting processed successfully with GPT-4o model

# %% [markdown]
# # Chain of Thought

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

base_prompt = ChatPromptTemplate.from_messages([
    ("system", "You are an expert educator that explains concepts clearly and concisely. You always reason step-by-step."),
    ("human", """
     Explain quantum mechanics basics to a complete beginner with no prior knowledge. Use simple analogies, no equations.
     Use simple analogies, no equations.
     4 short sections with headings.
     
     **Think step by step before answering:**
     1. Identify the 3-4 core concepts to explain.
     2. For each concept, find 1 simple analogy or example.
     3. Outline the structure (sections/headings).
     4. Check: simple language, no jargon, logical flow.
     5. Write the final explanation.

     Show your step-by-step reasoning FIRST, then the final answer.
     """)
])

chain = base_prompt | agent_openai_gpt4o | StrOutputParser()

# Zero Shot Example
print("🔷  Chain of Thought Prompt Response:")
print("=" * 60)

cot_response = chain.invoke({
})
print(cot_response)

print("\n\n✅  Chain of Thought prompting processed successfully with GPT-4o model")
# Out:
# 🔷  Chain of Thought Prompt Response:
# ============================================================
# **Step 1: Identify Core Concepts**
# 1. Wave-Particle Duality
# 2. Uncertainty Principle
# 3. Quantum Entanglement
# 4. Superposition
#
# **Step 2: Find Simple Analogies or Examples**
# 1. **Wave-Particle Duality**: Light behaving like both particles and waves can be compared to a person being both a teacher and a student.
# 2. **Uncertainty Principle**: Knowing the position or speed of a particle can be likened to trying to find a specific spot on a spinning basketball.
# 3. **Quantum Entanglement**: Two entangled particles are like a pair of gloves—knowing one is left-handed means the other is right-handed, even if they are far apart.
# 4. **Superposition**: A spinning coin that is both heads and tails until stopped is akin to particles existing in multiple states.
#
# **Step 3: Outline the Structure**
# 1. The Dual Nature of Light and Matter
# 2. The Unpredictable World
# 3. The Mysterious Connection
# 4. The Many States of Existence
#
# **Step 4: Check**
# - Use simple language without jargon.
# - Ensure a logical flow from general concepts to specific phenomena.
# - Provide clear, relatable analogies for each concept.
#
# **Final Explanation**
#
# **1. The Dual Nature of Light and Matter**
# Imagine you are a person who plays two roles: sometimes you are a teacher, and other times you are a student. In the world of quantum mechanics, light and small particles like electrons also play two different roles. They can act like tiny particles, which are like little solid objects, and at other times, they behave like waves, spreading out and covering areas. This dual nature is one of the most surprising aspects of the quantum world.
#
# **2. The Unpredictable World**
# Think about a spinning basketball. If you want to know exactly where a certain spot on the ball is, you can’t, because the ball is spinning too fast. Similarly, in quantum mechanics, if you try to measure the exact position of a particle, you might not be able to know its speed, and vice versa. This idea is known as the Uncertainty Principle, showing us that some things in the quantum world are fundamentally unpredictable.
#
# **3. The Mysterious Connection**
# Consider a pair of gloves—if you find a left-hand glove, you immediately know the other one is for the right hand, even if it's far away. In quantum mechanics, certain particles can become entangled, meaning they are mysteriously connected, no matter how far apart they are. Changing one will instantly affect the other. This strange connection is called quantum entanglement.
#
# **4. The Many States of Existence**
# Imagine flipping a coin and watching it spin in the air. As it spins, it’s neither heads nor tails; it's in a state of both until it lands. Similarly, in the quantum world, particles can exist in multiple states at once until we observe them. This idea is called superposition, where particles are in a mix of different possibilities until we check on them.
#
# These concepts form the foundation of quantum mechanics, offering a glimpse into the extraordinary and often counterintuitive nature of the microscopic world.

# %% [markdown]
# # Tree of Thought

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

base_prompt = ChatPromptTemplate.from_messages([
    ("system", """You are an expert educator that explains concepts clearly and concisely. 
     You are passionate in exploring various explanation strategies."""),
    ("human", """
     Explain quantum mechanics basics to a complete beginner with no prior knowledge. Use simple analogies, no equations.
     
     **Tree of Thought: Explore 3 analogy paths for explaining quantum weirdness, then pick BEST:**

     **Path 1: Everyday Objects** (coins, water drops, light bulbs)
     **Path 2: Nature Phenomena** (waves on pond, clouds, fireflies)  
     **Path 3: Magic Tricks** (disappearing coin, spinning plates, smoke/mirrors)

     For each path, write 2-3 sentences showing how you'd explain:
     - Wave-particle duality
     - Superposition  
     - Uncertainty principle

     Then:
     1. Score each path 1-10 (simplicity=clarity for beginners, memorability, intuition).
     2. Pick your SINGLE BEST path.
     3. Write FULL beginner overview (4 sections: What is quantum?, Wave-particle duality, Uncertainty, Superposition) 
     using ONLY that path's analogies.
     """)
])

chain = base_prompt | agent_openai_gpt4o | StrOutputParser()

# Zero Shot Example
print("🔷  Tree of Thought Prompt Response:")
print("=" * 60)

tot_response = chain.invoke({
})
print(tot_response)

print("\n\n✅  Tree of Thought prompting processed successfully with GPT-4o model")
# Out:
# 🔷  Tree of Thought Prompt Response:
# ============================================================
# **Path 1: Everyday Objects**
#
# - **Wave-particle duality:** Imagine a coin that sometimes behaves like a solid object you can hold, but at other times, it acts like a ripple on water. Quantum objects, like light, can be both waves and particles, just like our magical coin can switch between being a solid and a ripple.
#
# - **Superposition:** Picture a light bulb that can be both on and off at the same time, existing in a fuzzy state of both brightness and darkness until you look at it. Quantum particles can exist in multiple states simultaneously, like our peculiar light bulb.
#
# - **Uncertainty principle:** Think of trying to catch a water drop with your fingers. The harder you try to pinpoint its exact spot, the more it slips away and you lose track of its movement. Similarly, the more precisely we try to measure a quantum particle's position, the less we know about its speed, and vice versa.
#
# **Path 2: Nature Phenomena**
#
# - **Wave-particle duality:** Consider waves on a pond that sometimes appear as a series of ripples and other times as individual raindrops. Quantum objects can behave like both the ripples and the raindrops, switching between wave-like and particle-like behavior.
#
# - **Superposition:** Imagine a cloud that can simultaneously be in the shape of both a rabbit and a dragon until you look closely and force it to settle into one shape. Quantum particles can exist in multiple states at once, like our shape-shifting cloud.
#
# - **Uncertainty principle:** Think about fireflies flickering in a field. The more you try to focus on exactly where one is, the less you can be sure of how fast it's moving. Quantum particles have a similar trade-off between knowing their position and their speed.
#
# **Path 3: Magic Tricks**
#
# - **Wave-particle duality:** Picture a magic trick where a coin can disappear and reappear, sometimes seen as a solid coin and sometimes just as a flash of light. Quantum objects can be both particles and waves, much like this magical coin transforming before your eyes.
#
# - **Superposition:** Envision a spinning plate that can be in multiple states of spin at once, until the magician stops it to show a single position. Quantum particles can exist in multiple states simultaneously, like this multi-spinning plate.
#
# - **Uncertainty principle:** Imagine a trick with smoke and mirrors where the more you try to see the exact location of the disappearing object, the more its path becomes unclear. In quantum mechanics, the more precisely we try to measure one property of a particle, the less precisely we can measure another.
#
# **Scoring:**
#
# - **Path 1: Everyday Objects**
#   Simplicity: 8
#   Memorability: 7
#   Intuition: 8
#   Total Score: 23
#
# - **Path 2: Nature Phenomena**
#   Simplicity: 7
#   Memorability: 8
#   Intuition: 7
#   Total Score: 22
#
# - **Path 3: Magic Tricks**
#   Simplicity: 6
#   Memorability: 9
#   Intuition: 6
#   Total Score: 21
#
# **Chosen Path: Path 1: Everyday Objects**
#
# **Full Beginner Overview Using Path 1:**
#
# **What is Quantum?**
#
# Quantum mechanics is like peeking into a world where objects don’t follow the usual rules we’re used to. It's the study of the very small, like atoms and particles, where things can behave in surprising and mind-bending ways.
#
# **Wave-Particle Duality**
#
# Imagine a coin that you can hold in your hand. Now, picture that same coin acting like a ripple on a pond instead. In the quantum world, particles like light can behave both as solid particles and as wave-like ripples, just like our coin can switch between being a tangible object and an intangible ripple.
#
# **Uncertainty Principle**
#
# Think of trying to catch a water drop with your fingers. The more you try to grab it, the harder it is to know exactly where it is and how fast it's moving. In quantum mechanics, the more precisely we know where a particle is, the less accurately we can tell how fast it’s going, and vice versa. It’s a bit like trying to pin down that elusive water drop.
#
# **Superposition**
#
# Picture a light bulb that can be both on and off at the same time until you decide to look at it. Quantum particles can exist in multiple states simultaneously, much like our light bulb being in a fuzzy state of both brightness and darkness until you observe it and it chooses a state. This strange behavior is a cornerstone of quantum mechanics, showing how the quantum world defies our everyday expectations.
#
#
# ✅  Tree of Thought prompting processed successfully with GPT-4o model

# %% [markdown]
# # Chain of Density

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

base_prompt = ChatPromptTemplate.from_messages([
    ("system", "You are an expert educator that explains concepts clearly and concisely. You can always explain concisely."),
    ("human", """
     Explain quantum mechanics basics to a complete beginner with no prior knowledge. Use simple analogies, no equations.
     Use simple analogies, no equations.
     4 short sections with headings.
     
     **Chain-of-Density (3 versions):**
     Version 1: Basic overview with 3-5 key entities.
     Version 2: Add relationships/connections (+30% density).
     Version 3: Maximum density, all entities linked, no fluff.

     Pick your best final version.
     """)
])

chain = base_prompt | agent_openai_gpt4o | StrOutputParser()

# Zero Shot Example
print("🔷  Chain of Density Prompt Response:")
print("=" * 60)

cod_response = chain.invoke({
})
print(cod_response)

print("\n\n✅  Chain of Density prompting processed successfully with GPT-4o model")
# Out:
# 🔷  Chain of Density Prompt Response:
# ============================================================
# **Quantum Mechanics Basics for Beginners**
#
# **Version 3: Maximum Density**
#
# **1. The World of the Very Small**
#
# Imagine a giant library filled with books. Each book is like a molecule, which is made up of pages called atoms. If we go even smaller, the words on the pages are like particles: electrons, protons, and neutrons. Quantum mechanics is the rulebook for how these tiny particles behave, and it's quite different from the rules we know in our everyday world.
#
# **2. The Uncertain Dance**
#
# Think of particles as dancers at a masquerade ball. Instead of following a strict choreography, these dancers can appear and move in unexpected ways. This is because, in quantum mechanics, particles don’t have a definite position or speed until we observe them. This unpredictability is much like trying to predict where a feather will land in the wind.
#
# **3. The Magic of Superposition**
#
# Imagine your friend is playing a game where they hide behind one of two doors. In the quantum world, until you open a door, your friend is both behind the left door and the right door at the same time. This is superposition, where particles exist in multiple states simultaneously until observed.
#
# **4. Entanglement: The Invisible Connection**
#
# Picture two paired gloves: if you find the left glove, you instantly know the other is the right glove, no matter where it is. In quantum mechanics, entangled particles are like these gloves. If you change one, the other changes instantly, even if they are miles apart. This connection defies our usual understanding of distance and is one of the most intriguing aspects of quantum mechanics.
#
# This dense overview introduces you to the strange yet fascinating world of quantum mechanics, where particles dance unpredictably, exist in multiple states, and remain mysteriously connected.
#
#
# ✅  Chain of Density prompting processed successfully with GPT-4o model
