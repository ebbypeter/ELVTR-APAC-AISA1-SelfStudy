# %% [markdown]
# # Assignment 02
#
# ## Objectives
#
# - Design both poorly constructed and well-engineered prompts
# - Apply prompt engineering techniques and frameworks intentionally
# - Test the same prompts across different models
# - Reason about model behavior, strengths, and limitations
# - Clearly explain your findings in a business- and architecture-oriented way

# %% [markdown]
# ## Load Environment Variables
# All the environment variables, APIS keys etc are loaded in the `.env` file. Load it into memory.

# %%
import os
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()

print("ℹ️  Loaded environment variables from .env file")
# Out:
# ℹ️  Loaded environment variables from .env file

# %% [markdown]
# ## Initialize Wrappers
#
# Initialize the LLM Wrappers / Agents

# %%
# Imports
from langchain_openai import ChatOpenAI
from langchain_anthropic import ChatAnthropic

# OpenAI GPT-4o Client
agent_openai_gpt4o = ChatOpenAI(
    name="OpenAI GPT-4o",
    model="gpt-4o",
    temperature=0.7,
    api_key=os.getenv('OPENAI_API_KEY'),
    organization=os.getenv('OPENAI_ORG_ID') if os.getenv('OPENAI_ORG_ID') else None
) 
print("ℹ️  OpenAI client initialized successfully with GPT-4o mode")

# OpenAI GPT-5.2 Client
agent_openai_gpt52 = ChatOpenAI(
    name="OpenAI gpt-5.2",
    model="gpt-5.2",
    temperature=0.7,
    api_key=os.getenv('OPENAI_API_KEY'),
    organization=os.getenv('OPENAI_ORG_ID') if os.getenv('OPENAI_ORG_ID') else None
) 
print("ℹ️  OpenAI client initialized successfully with gpt-5.2 mode")

# Anthropic Claude Sonnet-4.5 Client
agent_anthropic_claudesonnet45 = ChatAnthropic(
    name="Anthropic Claude Sonnet-4.5",
    model="claude-sonnet-4-5",
    temperature=0.7,
    api_key=os.getenv('CLAUDE_API_KEY')
)
print("ℹ️  Anthropic client initialized successfully with Claude Sonnet-4.5 mode")
# Out:
# ℹ️  OpenAI client initialized successfully with GPT-4o mode
# ℹ️  OpenAI client initialized successfully with gpt-5.2 mode
# ℹ️  Anthropic client initialized successfully with Claude Sonnet-4.5 mode

# %% [markdown]
# ## Construct the Prompts

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# System Prompt
system_prompt = """
You are a Clinical Documentation & Knowledge Assistant that helps generate 
clinical summaries for healthcare professionals and 
clear explanations for patients based on provided patient histories.
"""

# Poorly Constructed Prompt
promptA_plain = """
Create a clinical summary and a patient note for the following patient history:
{patient_history}

Keep each output to about 1-2 short paragraphs or 4-7 bullet points.
"""

# Well Constructed Prompt (TCREI Framework)
promptB_structured = """
**Task**  
- Generate a concise clinical summary using standard medical terminology.
- Generate a clear, patient-friendly explanation of the situation.

**Context**  
{patient_history}

**Requirements**  
General Requirements
- Use only information explicitly present in the context.
- Do not add any medical facts not present in the context.
- Make the outputs easy for a clinician to quickly review and for a patient to understand.
- Keep each output to about 1-2 short paragraphs or 4-7 bullet points.

Clinical Summary Requirements
- Audience: Other Clinicans, Doctors.
- Focus on: key diagnoses, timeline, treatments tried, recent disease activity, current concerns.
- Use clear clinical language and structured, concise sentences.
- Do not include advice directed at the patient.

Patient explanation requirements
- Audience: The Patient.
- Write as you would speak to the patient. 
- Use personal pronouns such as “we” and “you” to help create a sense of relatability and trust.
- Use plain, non-technical language where possible. If medical terms are used, provide brief explanation of the term.
- Reassure appropriately without minimizinf their concerns.
- Do not give any new medical advice. Focus on explanation and framing.
- Organize the content in a way that is clear to the reader.
- Use direct language

**Examples (style only, not content)**

Clinical summary style example:
"55-year-old with long-standing hypertension and type 2 diabetes, recently hospitalised for NSTEMI. 
On dual antiplatelet therapy, high-intensity statin, ACE inhibitor, and beta-blocker. Glycaemic control suboptimal. 
Key issues: secondary prevention post-MI, medication adherence, and optimisation of BP and glucose."

Patient explanation style example (for a different imaginary case):
"You have a form of heart disease where one of the blood vessels supplying your heart became blocked. 
The treatments you're on now help keep your blood flowing and lower the chance of another event. 
Our focus is on your medicines, blood pressure, and sugar levels to protect your heart over time."

Use these examples only as style guides for tone and level of detail.

**Instructions (output format)**
Produce the following:

Clinical Summary
<Clinical summary here>

Patient Explanation
<patient explanation here>
"""

patient_history = """
The patient presents with poorly controlled type 2 diabetes mellitus, evidenced by a persistently elevated HbA1c 
and fasting blood glucose levels above recommended targets. 
There is early evidence of microvascular involvement, including intermittent paraesthesia in the feet and 
borderline microalbuminuria on recent testing. Blood pressure remains suboptimally controlled despite 
current therapy. The immediate priorities are to intensify glycaemic and blood pressure management, 
reinforce lifestyle modifications, and arrange close follow-up to mitigate progression of 
diabetic complications.
"""

promptA = ChatPromptTemplate.from_messages([
    ("system", system_prompt),
    ("user", promptA_plain)
])
print("ℹ️  Prompt A (Plain Prompt) initiated successfully")

promptB = ChatPromptTemplate.from_messages([
    ("system", system_prompt),
    ("user", promptB_structured)
])
print("ℹ️  Prompt B (Structured Prompt) constructed successfully")
# Out:
# ℹ️  Prompt A (Plain Prompt) initiated successfully
# ℹ️  Prompt B (Structured Prompt) constructed successfully

# %% [markdown]
# ## Define the chains

# %%
# Prompt A with OpenAI GPT-4o 
promptA_openai_gpt4o = promptA | agent_openai_gpt4o | StrOutputParser()
print("ℹ️  Prompt A x OpenAI-Gpt-4o initiated successfully")

# Prompt A with OpenAI GPT-5.2
promptA_openai_gpt52 = promptA | agent_openai_gpt52 | StrOutputParser()
print("ℹ️  Prompt A x OpenAI-Gpt-5.2 initiated successfully")
 
# Prompt A with Anthropic Claude Sonnet-4.5
promptA_anthropic_claudesonnet45 = promptA | agent_anthropic_claudesonnet45 | StrOutputParser()
print("ℹ️  Prompt A x Claude-Sonnet-4-5 initiated successfully")

# Prompt B with OpenAI GPT-4o 
promptB_openai_gpt4o = promptB | agent_openai_gpt4o | StrOutputParser()
print("ℹ️  Prompt B x OpenAI-Gpt4o initiated successfully")

# Prompt B with OpenAI GPT-5.2
promptB_openai_gpt52 = promptB | agent_openai_gpt52 | StrOutputParser()
print("ℹ️  Prompt B x OpenAI-Gpt-5.2 initiated successfully")
 
# Prompt B with Anthropic Claude Sonnet-4.5
promptB_anthropic_claudesonnet45 = promptB | agent_anthropic_claudesonnet45 | StrOutputParser()
print("ℹ️  Prompt B x Claude-Sonnet-4.5 initiated successfully")
# Out:
# ℹ️  Prompt A x OpenAI-Gpt4o initiated successfully
# ℹ️  Prompt A x OpenAI-Gpt5.2 initiated successfully
# ℹ️  Prompt A x Claude-Sonnet-4-5 initiated successfully
# ℹ️  Prompt B x OpenAI-Gpt4o initiated successfully
# ℹ️  Prompt B x OpenAI-Gpt5.2 initiated successfully
# ℹ️  Prompt B x Claude-Sonnet-4-5 initiated successfully

# %% [markdown]
# ## Invoke the Prompts

# %%
response_promptA_openAI_gpt4o = promptA_openai_gpt4o.invoke({
    "patient_history": patient_history
})
print("✅  Prompt A x OpenAI-Gpt-4o Invoked successfully")

response_promptA_openai_gpt52 = promptA_openai_gpt52.invoke({
    "patient_history": patient_history
})
print("✅  Prompt A x OpenAI-Gpt-5.2 Invoked successfully")

response_promptA_anthropic_claudesonnet45 = promptA_anthropic_claudesonnet45.invoke({
    "patient_history": patient_history
})
print("✅  Prompt A x Anthropic-ClaudeSonnet-4.5 Invoked successfully")

response_promptB_openai_gpt4o = promptB_openai_gpt4o.invoke({
    "patient_history": patient_history
})
print("✅  Prompt B x OpenAI-Gpt-4o Invoked successfully")

response_promptB_openai_gpt52 = promptB_openai_gpt52.invoke({
    "patient_history": patient_history
})
print("✅  Prompt B x OpenAI-Gpt-5.2 Invoked successfully")

response_promptB_anthropic_claudesonnet45 = promptB_anthropic_claudesonnet45.invoke({
    "patient_history": patient_history
})
print("✅  Prompt B x Anthropic-ClaudeSonnet-4.5 Invoked successfully")
# Out:
# ✅  Prompt A x OpenAI-Gpt4o Invoked successfully
# ✅  Prompt A x OpenAI-Gpt5.2 Invoked successfully
# ✅  Prompt A x Anthropic-ClaudeSonnet-4.5 Invoked successfully
# ✅  Prompt B x OpenAI-Gpt4o Invoked successfully
# ✅  Prompt B x OpenAI-Gpt5.2 Invoked successfully
# ✅  Prompt B x Anthropic-ClaudeSonnet-4.5 Invoked successfully

# %% [markdown]
# ## Responses

# %% [markdown]
# ### Prompt A

# %%
promptAText = promptA.format(patient_history=patient_history)
print(f"Prompt: \n\n{promptAText}")
print("=" * 60)

print(f"\nOpenAI GPT-4o Response to Prompt A:")
print("-" * 60)
print(f"{response_promptA_openAI_gpt4o}")

print(f"\nOpenAI GPT-5.2 Response to Prompt A:")
print("-" * 60)
print(f"{response_promptA_openai_gpt52}")

print(f"\nAnthropic Claude Sonnet-4.5 Response to Prompt A:")
print("-" * 60)
print(f"{response_promptA_anthropic_claudesonnet45}")
# Out:
# Prompt:
#
# System:
# You are a Clinical Documentation & Knowledge Assistant that helps generate
# clinical summaries for healthcare professionals and
# clear explanations for patients based on provided patient histories.
#
# Human:
# Create a clinical summary and a patient note for the following patient history:
#
# The patient presents with poorly controlled type 2 diabetes mellitus, evidenced by a persistently elevated HbA1c
# and fasting blood glucose levels above recommended targets.
# There is early evidence of microvascular involvement, including intermittent paraesthesia in the feet and
# borderline microalbuminuria on recent testing. Blood pressure remains suboptimally controlled despite
# current therapy. The immediate priorities are to intensify glycaemic and blood pressure management,
# reinforce lifestyle modifications, and arrange close follow-up to mitigate progression of
# diabetic complications.
#
#
# Keep each output to about 1-2 short paragraphs or 4-7 bullet points.
#
# ============================================================
#
# OpenAI GPT-4o Response to Prompt A:
# ------------------------------------------------------------
# **Clinical Summary:**
#
# The patient is experiencing poorly controlled type 2 diabetes mellitus, with persistently elevated HbA1c and fasting blood glucose levels that exceed recommended targets. Early signs of microvascular complications are present, including intermittent paraesthesia in the feet and borderline microalbuminuria. Blood pressure control is suboptimal despite ongoing treatment. The primary objectives are to enhance glycaemic and blood pressure management, reinforce lifestyle modifications, and ensure close monitoring to prevent the progression of diabetic complications.
#
# **Patient Note:**
#
# - Your blood sugar levels and HbA1c indicate that your diabetes is not well-controlled.
# - You've started to experience some nerve issues in your feet and a slight change in kidney function, which can happen with diabetes.
# - Your blood pressure is also higher than it should be, even with your current medication.
# - It's important to work on getting your blood sugar and blood pressure under better control.
# - We'll review your diet and exercise habits and make any necessary changes.
# - We'll schedule regular follow-ups to closely monitor your progress and adjust your treatment plan as needed.
#
# OpenAI GPT-5.2 Response to Prompt A:
# ------------------------------------------------------------
# ## Clinical Summary (for healthcare professionals)
# - Poorly controlled **type 2 diabetes mellitus** with **persistently elevated HbA1c** and **fasting glucose above target**, indicating inadequate glycaemic control on current regimen.
# - Early **microvascular involvement**: intermittent **distal foot paraesthesia** concerning for emerging peripheral neuropathy; **borderline microalbuminuria** suggesting early diabetic kidney disease.
# - **Blood pressure suboptimally controlled** despite current antihypertensive therapy, increasing risk for progression of nephropathy and other complications.
# - Priorities: **intensify glycaemic therapy** (review adherence, regimen optimization/step-up, consider agents with renal/CV benefit as appropriate), **optimize BP management** (confirm home readings, titrate/add agents; ensure ACEi/ARB if albuminuria and no contraindications), and reinforce **nutrition/weight/activity** interventions.
# - Plan: close follow-up for medication titration and safety monitoring; repeat labs (HbA1c, BMP/eGFR, urine ACR), assess neuropathy/foot exam, and address comprehensive risk reduction.
#
# ## Patient Note (clear explanation for the patient)
# - Your blood sugars have been running **higher than recommended** for some time, based on your HbA1c and fasting readings.
# - You’re starting to show **early signs of diabetes-related effects**: occasional tingling/numbness in your feet and a **small amount of protein in the urine**, which can be an early sign of kidney stress.
# - Your **blood pressure is still higher than goal**, which can worsen diabetes complications, especially for the kidneys and heart.
# - Next steps are to **adjust your diabetes and blood pressure medicines**, and to double down on lifestyle steps (meal planning, physical activity, weight goals, and limiting salt).
# - We’ll arrange **close follow-up** and repeat tests soon to make sure the new plan is working and to protect your nerves, kidneys, eyes, and heart.
#
# Anthropic Claude Sonnet-4.5 Response to Prompt A:
# ------------------------------------------------------------
# # Clinical Summary
#
# **Patient:** Type 2 Diabetes Mellitus - Poorly Controlled with Early Complications
#
# **Key Findings:**
# - Persistently elevated HbA1c and fasting glucose above target ranges
# - Early microvascular complications: intermittent peripheral neuropathy (foot paraesthesia) and borderline microalbuminuria
# - Suboptimal blood pressure control on current antihypertensive regimen
#
# **Management Plan:**
# - Intensify glycemic control: consider medication adjustment/addition to current diabetic regimen
# - Optimize blood pressure management: titrate or add antihypertensive agents
# - Reinforce lifestyle modifications: diet, exercise, weight management
# - Close follow-up scheduled to monitor treatment response and prevent progression of diabetic complications
# - Consider referral for diabetic education and podiatry assessment
#
# ---
#
# # Patient Note
#
# **What's happening:** Your diabetes is not as well controlled as we'd like it to be, and your blood sugar levels have been running higher than our target. We've also found some early signs that diabetes may be affecting your nerves (the tingling in your feet) and kidneys (small amounts of protein in your urine). Your blood pressure also needs better control.
#
# **What we're going to do:**
# - Adjust your diabetes medications to better control your blood sugar
# - Change your blood pressure medications to get better control
# - Work together on diet and exercise improvements
# - Schedule regular follow-up appointments to monitor your progress
# - These changes will help prevent diabetes from causing more serious problems with your eyes, kidneys, nerves, and heart
#
# **What you can do:** Take your medications as prescribed, monitor your blood sugar at home, follow a healthy diet, stay active, and keep all your follow-up appointments.

# %% [markdown]
# ### Prompt B

# %%
promptBText = promptB.format(patient_history=patient_history)
print(f"Prompt: \n\n{promptBText}\n")
print("=" * 60)

print(f"\nOpenAI GPT-4o Response to Prompt B:")
print("-" * 60)
print(f"{response_promptB_openai_gpt4o}")

print(f"\nOpenAI GPT-5.2 Response to Prompt B:")
print("-" * 60)
print(f"{response_promptB_openai_gpt52}")

print(f"\nAnthropic Claude Sonnet-4.5 Response to Prompt B:")
print("-" * 60)
print(f"{response_promptB_anthropic_claudesonnet45}")
# Out:
# Prompt:
#
# System:
# You are a Clinical Documentation & Knowledge Assistant that helps generate
# clinical summaries for healthcare professionals and
# clear explanations for patients based on provided patient histories.
#
# Human:
# **Task**
# - Generate a concise clinical summary using standard medical terminology.
# - Generate a clear, patient-friendly explanation of the situation.
#
# **Context**
#
# The patient presents with poorly controlled type 2 diabetes mellitus, evidenced by a persistently elevated HbA1c
# and fasting blood glucose levels above recommended targets.
# There is early evidence of microvascular involvement, including intermittent paraesthesia in the feet and
# borderline microalbuminuria on recent testing. Blood pressure remains suboptimally controlled despite
# current therapy. The immediate priorities are to intensify glycaemic and blood pressure management,
# reinforce lifestyle modifications, and arrange close follow-up to mitigate progression of
# diabetic complications.
#
#
# **Requirements**
# General Requirements
# - Use only information explicitly present in the context.
# - Do not add any medical facts not present in the context.
# - Make the outputs easy for a clinician to quickly review and for a patient to understand.
# - Keep each output to about 1-2 short paragraphs or 4-7 bullet points.
#
# Clinical Summary Requirements
# - Audience: Other Clinicans, Doctors.
# - Focus on: key diagnoses, timeline, treatments tried, recent disease activity, current concerns.
# - Use clear clinical language and structured, concise sentences.
# - Do not include advice directed at the patient.
#
# Patient explanation requirements
# - Audience: The Patient.
# - Write as you would speak to the patient.
# - Use personal pronouns such as “we” and “you” to help create a sense of relatability and trust.
# - Use plain, non-technical language where possible. If medical terms are used, provide brief explanation of the term.
# - Reassure appropriately without minimizinf their concerns.
# - Do not give any new medical advice. Focus on explanation and framing.
# - Organize the content in a way that is clear to the reader.
# - Use direct language
#
# **Examples (style only, not content)**
#
# Clinical summary style example:
# "55-year-old with long-standing hypertension and type 2 diabetes, recently hospitalised for NSTEMI.
# On dual antiplatelet therapy, high-intensity statin, ACE inhibitor, and beta-blocker. Glycaemic control suboptimal.
# Key issues: secondary prevention post-MI, medication adherence, and optimisation of BP and glucose."
#
# Patient explanation style example (for a different imaginary case):
# "You have a form of heart disease where one of the blood vessels supplying your heart became blocked.
# The treatments you're on now help keep your blood flowing and lower the chance of another event.
# Our focus is on your medicines, blood pressure, and sugar levels to protect your heart over time."
#
# Use these examples only as style guides for tone and level of detail.
#
# **Instructions (output format)**
# Produce the following:
#
# Clinical Summary
# <Clinical summary here>
#
# Patient Explanation
# <patient explanation here>
#
#
# ============================================================
#
# OpenAI GPT-4o Response to Prompt B:
# ------------------------------------------------------------
# **Clinical Summary**
# The patient exhibits poorly controlled type 2 diabetes mellitus, with persistently elevated HbA1c and fasting blood glucose levels exceeding target. Early microvascular complications are evident, including intermittent paraesthesia in the feet and borderline microalbuminuria. Blood pressure control is suboptimal despite current therapeutic measures. Immediate priorities include intensifying glycaemic and blood pressure management, reinforcing lifestyle modifications, and scheduling close follow-up to prevent progression of diabetic complications.
#
# **Patient Explanation**
# You have type 2 diabetes, and right now, your blood sugar levels are higher than what we want them to be. This has started to affect some small blood vessels, which is why you're feeling some tingling in your feet and have slight changes in your kidney tests. Your blood pressure is also a bit higher than we’d like, even with your current treatment. Our main goals are to help you manage your blood sugar and blood pressure better, support you with healthy lifestyle changes, and keep a close eye on things to prevent any further issues.
#
# OpenAI GPT-5.2 Response to Prompt B:
# ------------------------------------------------------------
# Clinical Summary
# - Poorly controlled type 2 diabetes mellitus with persistently elevated HbA1c and fasting blood glucose above recommended targets.
# - Early microvascular involvement suggested by intermittent paraesthesia in the feet and borderline microalbuminuria on recent testing.
# - Blood pressure remains suboptimally controlled despite current therapy.
# - Current concerns/priorities: need to intensify glycaemic and blood pressure management, reinforce lifestyle modifications, and arrange close follow-up to reduce risk of progression of diabetic complications.
#
# Patient Explanation
# - Your type 2 diabetes is not as well controlled as we want right now, based on your longer-term sugar test (HbA1c) and your fasting blood sugar readings being higher than target.
# - We’re also seeing early signs that high sugar may be starting to affect small blood vessels and nerves: you’ve had occasional tingling/numbness in your feet (paraesthesia), and your urine test showed a borderline amount of protein (microalbuminuria), which can be an early sign of kidney stress.
# - Your blood pressure is also still higher than we want, even with your current treatment.
# - The main focus now is to tighten control of your blood sugar and blood pressure and to keep a close eye on things, to lower the chance of these early changes getting worse over time.
#
# Anthropic Claude Sonnet-4.5 Response to Prompt B:
# ------------------------------------------------------------
# **Clinical Summary**
#
# This patient has poorly controlled type 2 diabetes mellitus with persistently elevated HbA1c and fasting glucose above target ranges. Early microvascular complications are emerging, including intermittent peripheral paraesthesia and borderline microalbuminuria, suggesting early diabetic neuropathy and nephropathy. Blood pressure control remains suboptimal on current antihypertensive therapy. Immediate management priorities include intensification of both glycaemic and antihypertensive regimens, reinforcement of lifestyle interventions, and establishment of close interval follow-up to prevent progression of diabetic microvascular disease.
#
# **Patient Explanation**
#
# Your diabetes isn't as well controlled as we'd like it to be right now. The blood sugar tests we've been monitoring show levels that are higher than our target, which over time can affect different parts of your body. We're seeing some early signs that this is starting to happen—the tingling you've been feeling in your feet and some changes in your kidney function tests suggest your nerves and kidneys are being affected by the high sugar levels. Your blood pressure also needs better control.
#
# The good news is we've caught this early, and we can take action now. We need to adjust your medications to get both your blood sugar and blood pressure down to safer levels. We'll also work together on diet and activity changes that can help. We'll see you more frequently over the coming weeks to make sure we're getting things back on track and preventing any further problems.
