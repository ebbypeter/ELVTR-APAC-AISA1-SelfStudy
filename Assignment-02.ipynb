# %% [markdown]
# # Assignment 02 - Prompt Engineering
#
# ## Objectives
#
# - Design both poorly constructed and well-engineered prompts
# - Apply prompt engineering techniques and frameworks intentionally
# - Test the same prompts across different models
# - Reason about model behavior, strengths, and limitations
# - Clearly explain your findings in a business- and architecture-oriented way

# %% [markdown]
# ## Load Environment Variables
# All the environment variables, APIS keys etc are loaded in the `.env` file. Load it into memory.

# %%
import os
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()

print("ℹ️  Loaded environment variables from .env file")
# Out:
# ℹ️  Loaded environment variables from .env file

# %% [markdown]
# ## Initialize Wrappers
#
# Initialize the LLM Wrappers / Agents

# %%
# Imports
from langchain_openai import ChatOpenAI
from langchain_anthropic import ChatAnthropic

# OpenAI GPT-4o Client
agent_openai_gpt4o = ChatOpenAI(
    name="OpenAI GPT-4o",
    model="gpt-4o",
    temperature=0.7,
    api_key=os.getenv('OPENAI_API_KEY'),
    organization=os.getenv('OPENAI_ORG_ID') if os.getenv('OPENAI_ORG_ID') else None
) 
print("ℹ️  OpenAI client initialized successfully with GPT-4o mode")

# OpenAI GPT-5.2 Client
agent_openai_gpt52 = ChatOpenAI(
    name="OpenAI gpt-5.2",
    model="gpt-5.2",
    temperature=0.7,
    api_key=os.getenv('OPENAI_API_KEY'),
    organization=os.getenv('OPENAI_ORG_ID') if os.getenv('OPENAI_ORG_ID') else None
) 
print("ℹ️  OpenAI client initialized successfully with gpt-5.2 mode")

# Anthropic Claude Sonnet-4.5 Client
agent_anthropic_claudesonnet45 = ChatAnthropic(
    name="Anthropic Claude Sonnet-4.5",
    model="claude-sonnet-4-5",
    temperature=0.7,
    api_key=os.getenv('CLAUDE_API_KEY')
)
print("ℹ️  Anthropic client initialized successfully with Claude Sonnet-4.5 mode")
# Out:
# c:\Users\ebbyp\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\langchain_core\_api\deprecation.py:26: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1
# ℹ️  OpenAI client initialized successfully with GPT-4o mode
# ℹ️  OpenAI client initialized successfully with gpt-5.2 mode
# ℹ️  Anthropic client initialized successfully with Claude Sonnet-4.5 mode

# %% [markdown]
# ## Construct the Prompts

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# Patient History
patient_history = """
The patient presents with poorly controlled type 2 diabetes mellitus, evidenced by a persistently elevated HbA1c 
and fasting blood glucose levels above recommended targets. 
There is early evidence of microvascular involvement, including intermittent paraesthesia in the feet and 
borderline microalbuminuria on recent testing. Blood pressure remains suboptimally controlled despite 
current therapy. The immediate priorities are to intensify glycaemic and blood pressure management, 
reinforce lifestyle modifications, and arrange close follow-up to mitigate progression of 
diabetic complications.
"""

# System Prompt
system_prompt = """
You are a Clinical Documentation & Knowledge Assistant that helps generate 
clinical summaries for healthcare professionals and 
clear explanations for patients based on provided patient histories.
"""

# Poorly Constructed Prompt
promptA_plain = """
Create a clinical summary and a patient note for the following patient history:
{patient_history}

Keep each output to about 1-2 short paragraphs or 4-7 bullet points.
"""

# Well Constructed Prompt (TCREI Framework)
promptB_structured = """
**Task**  
- Generate a concise clinical summary using standard medical terminology.
- Generate a clear, patient-friendly explanation of the situation.

**Context**  
{patient_history}

**Requirements**  
General Requirements
- Use only information explicitly present in the context.
- Do not add any medical facts not present in the context.
- Make the outputs easy for a clinician to quickly review and for a patient to understand.
- Keep each output to about 1-2 short paragraphs or 4-7 bullet points.

Clinical Summary Requirements
- Audience: Other Clinicans, Doctors.
- Focus on: key diagnoses, timeline, treatments tried, recent disease activity, current concerns.
- Use clear clinical language and structured, concise sentences.
- Do not include advice directed at the patient.

Patient explanation requirements
- Audience: The Patient.
- Write as you would speak to the patient. 
- Use personal pronouns such as “we” and “you” to help create a sense of relatability and trust.
- Use plain, non-technical language where possible. If medical terms are used, provide brief explanation of the term.
- Reassure appropriately without minimizinf their concerns.
- Do not give any new medical advice. Focus on explanation and framing.
- Organize the content in a way that is clear to the reader.
- Use direct language

**Examples (style only, not content)**

Clinical summary style example:
"55-year-old with long-standing hypertension and type 2 diabetes, recently hospitalised for NSTEMI. 
On dual antiplatelet therapy, high-intensity statin, ACE inhibitor, and beta-blocker. Glycaemic control suboptimal. 
Key issues: secondary prevention post-MI, medication adherence, and optimisation of BP and glucose."

Patient explanation style example (for a different imaginary case):
"You have a form of heart disease where one of the blood vessels supplying your heart became blocked. 
The treatments you're on now help keep your blood flowing and lower the chance of another event. 
Our focus is on your medicines, blood pressure, and sugar levels to protect your heart over time."

Use these examples only as style guides for tone and level of detail.

**Instructions (output format)**
Produce the following:

Clinical Summary
<Clinical summary here>

Patient Explanation
<patient explanation here>
"""

promptA = ChatPromptTemplate.from_messages([
    ("system", system_prompt),
    ("user", promptA_plain)
])
print("ℹ️  Prompt A (Plain Prompt) initiated successfully")

promptB = ChatPromptTemplate.from_messages([
    ("system", system_prompt),
    ("user", promptB_structured)
])
print("ℹ️  Prompt B (Structured Prompt) constructed successfully")
# Out:
# ℹ️  Prompt A (Plain Prompt) initiated successfully
# ℹ️  Prompt B (Structured Prompt) constructed successfully

# %% [markdown]
# ## Define the chains

# %%
# Prompt A with OpenAI GPT-4o 
promptA_openai_gpt4o = promptA | agent_openai_gpt4o | StrOutputParser()
print("ℹ️  Prompt A x OpenAI-Gpt-4o initiated successfully")

# Prompt A with OpenAI GPT-5.2
promptA_openai_gpt52 = promptA | agent_openai_gpt52 | StrOutputParser()
print("ℹ️  Prompt A x OpenAI-Gpt-5.2 initiated successfully")
 
# Prompt A with Anthropic Claude Sonnet-4.5
promptA_anthropic_claudesonnet45 = promptA | agent_anthropic_claudesonnet45 | StrOutputParser()
print("ℹ️  Prompt A x Claude-Sonnet-4-5 initiated successfully")

# Prompt B with OpenAI GPT-4o 
promptB_openai_gpt4o = promptB | agent_openai_gpt4o | StrOutputParser()
print("ℹ️  Prompt B x OpenAI-Gpt4o initiated successfully")

# Prompt B with OpenAI GPT-5.2
promptB_openai_gpt52 = promptB | agent_openai_gpt52 | StrOutputParser()
print("ℹ️  Prompt B x OpenAI-Gpt-5.2 initiated successfully")
 
# Prompt B with Anthropic Claude Sonnet-4.5
promptB_anthropic_claudesonnet45 = promptB | agent_anthropic_claudesonnet45 | StrOutputParser()
print("ℹ️  Prompt B x Claude-Sonnet-4.5 initiated successfully")
# Out:
# ℹ️  Prompt A x OpenAI-Gpt-4o initiated successfully
# ℹ️  Prompt A x OpenAI-Gpt-5.2 initiated successfully
# ℹ️  Prompt A x Claude-Sonnet-4-5 initiated successfully
# ℹ️  Prompt B x OpenAI-Gpt4o initiated successfully
# ℹ️  Prompt B x OpenAI-Gpt-5.2 initiated successfully
# ℹ️  Prompt B x Claude-Sonnet-4.5 initiated successfully

# %% [markdown]
# ## Invoke the Prompts

# %%
response_promptA_openAI_gpt4o = promptA_openai_gpt4o.invoke({
    "patient_history": patient_history
})
print("✅  Prompt A x OpenAI-Gpt-4o Invoked successfully")

response_promptA_openai_gpt52 = promptA_openai_gpt52.invoke({
    "patient_history": patient_history
})
print("✅  Prompt A x OpenAI-Gpt-5.2 Invoked successfully")

response_promptA_anthropic_claudesonnet45 = promptA_anthropic_claudesonnet45.invoke({
    "patient_history": patient_history
})
print("✅  Prompt A x Anthropic-ClaudeSonnet-4.5 Invoked successfully")

response_promptB_openai_gpt4o = promptB_openai_gpt4o.invoke({
    "patient_history": patient_history
})
print("✅  Prompt B x OpenAI-Gpt-4o Invoked successfully")

response_promptB_openai_gpt52 = promptB_openai_gpt52.invoke({
    "patient_history": patient_history
})
print("✅  Prompt B x OpenAI-Gpt-5.2 Invoked successfully")

response_promptB_anthropic_claudesonnet45 = promptB_anthropic_claudesonnet45.invoke({
    "patient_history": patient_history
})
print("✅  Prompt B x Anthropic-ClaudeSonnet-4.5 Invoked successfully")
# Out:
# ✅  Prompt A x OpenAI-Gpt-4o Invoked successfully
# ✅  Prompt A x OpenAI-Gpt-5.2 Invoked successfully
# ✅  Prompt A x Anthropic-ClaudeSonnet-4.5 Invoked successfully
# ✅  Prompt B x OpenAI-Gpt-4o Invoked successfully
# ✅  Prompt B x OpenAI-Gpt-5.2 Invoked successfully
# ✅  Prompt B x Anthropic-ClaudeSonnet-4.5 Invoked successfully

# %% [markdown]
# ## Responses

# %% [markdown]
# ### Prompt A

# %%
promptAText = promptA.format(patient_history=patient_history)
print(f"Prompt: \n\n{promptAText}")
print("=" * 60)

print(f"\nOpenAI GPT-4o Response to Prompt A:")
print("-" * 60)
print(f"{response_promptA_openAI_gpt4o}")

print(f"\nOpenAI GPT-5.2 Response to Prompt A:")
print("-" * 60)
print(f"{response_promptA_openai_gpt52}")

print(f"\nAnthropic Claude Sonnet-4.5 Response to Prompt A:")
print("-" * 60)
print(f"{response_promptA_anthropic_claudesonnet45}")
# Out:
# Prompt:
#
# System:
# You are a Clinical Documentation & Knowledge Assistant that helps generate
# clinical summaries for healthcare professionals and
# clear explanations for patients based on provided patient histories.
#
# Human:
# Create a clinical summary and a patient note for the following patient history:
#
# The patient presents with poorly controlled type 2 diabetes mellitus, evidenced by a persistently elevated HbA1c
# and fasting blood glucose levels above recommended targets.
# There is early evidence of microvascular involvement, including intermittent paraesthesia in the feet and
# borderline microalbuminuria on recent testing. Blood pressure remains suboptimally controlled despite
# current therapy. The immediate priorities are to intensify glycaemic and blood pressure management,
# reinforce lifestyle modifications, and arrange close follow-up to mitigate progression of
# diabetic complications.
#
#
# Keep each output to about 1-2 short paragraphs or 4-7 bullet points.
#
# ============================================================
#
# OpenAI GPT-4o Response to Prompt A:
# ------------------------------------------------------------
# **Clinical Summary:**
#
# The patient is experiencing poorly controlled type 2 diabetes mellitus, demonstrated by persistently elevated HbA1c levels and fasting blood glucose readings above target. Early signs of microvascular complications are present, including intermittent paraesthesia in the feet and borderline microalbuminuria. Blood pressure control is inadequate despite ongoing treatment. The primary focus should be on enhancing glycaemic and blood pressure management, emphasizing lifestyle modifications, and scheduling frequent follow-ups to prevent further diabetic complications.
#
# **Patient Note:**
#
# - Your blood sugar levels have been higher than recommended, which affects your overall health.
# - There are early signs of nerve and kidney involvement due to diabetes, such as tingling in your feet and changes in your kidney tests.
# - Your current blood pressure medication is not fully controlling your blood pressure.
# - We need to improve your blood sugar and blood pressure management, and review your medication and lifestyle habits.
# - Regular follow-ups will be important to help prevent further health issues related to diabetes.
#
# OpenAI GPT-5.2 Response to Prompt A:
# ------------------------------------------------------------
# ## Clinical Summary (for healthcare professionals)
# - **Problem list:** Poorly controlled **T2DM** (persistently elevated HbA1c; fasting BG above target), **suboptimally controlled hypertension** on current therapy.
# - **Complications/early end-organ involvement:** Symptoms consistent with **early peripheral neuropathy** (intermittent foot paraesthesia) and **early nephropathy risk** (borderline microalbuminuria).
# - **Risk assessment:** Ongoing hyperglycaemia and elevated BP increase risk of progression of microvascular disease (neuropathy/nephropathy/retinopathy) and macrovascular events.
# - **Priorities/plan:** **Intensify glycaemic therapy** (review adherence, diet, SMBG/CGM data, consider escalation/add-on agents per comorbidities), **optimize BP regimen** (confirm home readings, titrate/add agents; consider ACEi/ARB especially with albuminuria), reinforce lifestyle interventions (weight, nutrition, activity), and address preventive care (lipids, smoking, vaccines).
# - **Monitoring/follow-up:** Repeat **UACR** and renal function, foot exam/neuropathy assessment, and arrange **close follow-up** to assess response and side effects; ensure retinal screening as indicated.
#
# ## Patient Note (plain language)
# - Your blood sugar levels have been running **higher than recommended**, and this increases the chance of diabetes-related problems over time.
# - You’re starting to show **early signs of diabetes affecting small nerves and kidneys**: tingling/numbness in the feet at times and a urine test that suggests the kidneys may be under strain.
# - Your **blood pressure is also higher than we want**, which can speed up these complications.
# - Next steps are to **adjust your diabetes and blood pressure treatment**, and to strengthen daily habits (healthy eating plan, regular activity, weight goals, and taking medicines consistently).
# - We’ll arrange **closer follow-up and repeat tests** (blood sugar tracking, kidney/urine checks, and foot/eye screening) to help prevent these issues from getting worse.
#
# Anthropic Claude Sonnet-4.5 Response to Prompt A:
# ------------------------------------------------------------
# # Clinical Summary
#
# **Patient:** Type 2 Diabetes Mellitus - Poorly Controlled with Early Complications
#
# **Key Findings:**
# - Persistently elevated HbA1c and fasting glucose above target ranges
# - Early microvascular complications: intermittent peripheral neuropathy (foot paraesthesia) and borderline microalbuminuria
# - Suboptimal blood pressure control on current antihypertensive regimen
#
# **Management Plan:**
# - Intensify diabetes therapy to achieve glycemic targets
# - Optimize blood pressure management (consider ACE inhibitor/ARB for renal protection)
# - Reinforce lifestyle modifications: diet, exercise, weight management
# - Arrange close follow-up (2-4 weeks) to monitor response and prevent complication progression
# - Consider referral to diabetes educator and dietitian
# - Screen for additional diabetic complications (retinopathy, cardiovascular risk assessment)
#
# ---
#
# # Patient Note
#
# **What's Happening:**
# Your diabetes is not as well controlled as we'd like it to be. Your blood sugar levels and HbA1c (a measure of your average sugar over 3 months) are higher than our target. We've also noticed some early signs that diabetes may be affecting your nerves (the tingling in your feet) and kidneys (small amounts of protein in your urine). Your blood pressure also needs better control.
#
# **What We're Going to Do:**
# - Adjust your diabetes medications to better control your blood sugar
# - Review your blood pressure medications to protect your kidneys
# - Work together on diet and exercise improvements
# - See you back soon (within a month) to check how things are improving
# - These changes will help prevent diabetes from causing more serious problems with your eyes, kidneys, nerves, and heart

# %% [markdown]
# ### Prompt B

# %%
promptBText = promptB.format(patient_history=patient_history)
print(f"Prompt: \n\n{promptBText}\n")
print("=" * 60)

print(f"\nOpenAI GPT-4o Response to Prompt B:")
print("-" * 60)
print(f"{response_promptB_openai_gpt4o}")

print(f"\nOpenAI GPT-5.2 Response to Prompt B:")
print("-" * 60)
print(f"{response_promptB_openai_gpt52}")

print(f"\nAnthropic Claude Sonnet-4.5 Response to Prompt B:")
print("-" * 60)
print(f"{response_promptB_anthropic_claudesonnet45}")
# Out:
# Prompt:
#
# System:
# You are a Clinical Documentation & Knowledge Assistant that helps generate
# clinical summaries for healthcare professionals and
# clear explanations for patients based on provided patient histories.
#
# Human:
# **Task**
# - Generate a concise clinical summary using standard medical terminology.
# - Generate a clear, patient-friendly explanation of the situation.
#
# **Context**
#
# The patient presents with poorly controlled type 2 diabetes mellitus, evidenced by a persistently elevated HbA1c
# and fasting blood glucose levels above recommended targets.
# There is early evidence of microvascular involvement, including intermittent paraesthesia in the feet and
# borderline microalbuminuria on recent testing. Blood pressure remains suboptimally controlled despite
# current therapy. The immediate priorities are to intensify glycaemic and blood pressure management,
# reinforce lifestyle modifications, and arrange close follow-up to mitigate progression of
# diabetic complications.
#
#
# **Requirements**
# General Requirements
# - Use only information explicitly present in the context.
# - Do not add any medical facts not present in the context.
# - Make the outputs easy for a clinician to quickly review and for a patient to understand.
# - Keep each output to about 1-2 short paragraphs or 4-7 bullet points.
#
# Clinical Summary Requirements
# - Audience: Other Clinicans, Doctors.
# - Focus on: key diagnoses, timeline, treatments tried, recent disease activity, current concerns.
# - Use clear clinical language and structured, concise sentences.
# - Do not include advice directed at the patient.
#
# Patient explanation requirements
# - Audience: The Patient.
# - Write as you would speak to the patient.
# - Use personal pronouns such as “we” and “you” to help create a sense of relatability and trust.
# - Use plain, non-technical language where possible. If medical terms are used, provide brief explanation of the term.
# - Reassure appropriately without minimizinf their concerns.
# - Do not give any new medical advice. Focus on explanation and framing.
# - Organize the content in a way that is clear to the reader.
# - Use direct language
#
# **Examples (style only, not content)**
#
# Clinical summary style example:
# "55-year-old with long-standing hypertension and type 2 diabetes, recently hospitalised for NSTEMI.
# On dual antiplatelet therapy, high-intensity statin, ACE inhibitor, and beta-blocker. Glycaemic control suboptimal.
# Key issues: secondary prevention post-MI, medication adherence, and optimisation of BP and glucose."
#
# Patient explanation style example (for a different imaginary case):
# "You have a form of heart disease where one of the blood vessels supplying your heart became blocked.
# The treatments you're on now help keep your blood flowing and lower the chance of another event.
# Our focus is on your medicines, blood pressure, and sugar levels to protect your heart over time."
#
# Use these examples only as style guides for tone and level of detail.
#
# **Instructions (output format)**
# Produce the following:
#
# Clinical Summary
# <Clinical summary here>
#
# Patient Explanation
# <patient explanation here>
#
#
# ============================================================
#
# OpenAI GPT-4o Response to Prompt B:
# ------------------------------------------------------------
# **Clinical Summary**
# The patient is managing poorly controlled type 2 diabetes mellitus, as indicated by persistently elevated HbA1c and fasting blood glucose levels exceeding recommended targets. There is early evidence of microvascular complications, including intermittent paraesthesia in the feet and borderline microalbuminuria. Blood pressure remains inadequately controlled despite current treatment. Immediate priorities include intensifying glycaemic and blood pressure management, reinforcing lifestyle modifications, and ensuring close follow-up to prevent progression of diabetic complications.
#
# **Patient Explanation**
# You are currently dealing with type 2 diabetes that isn't as well controlled as we would like. Your blood sugar levels, as shown by your recent tests, are higher than the targets we aim for. This has started to affect your small blood vessels, which is why you might be experiencing tingling in your feet and changes in your kidney function tests. Your blood pressure is also higher than we want, even with your current medication. Our main focus now is to work together on improving your blood sugar and blood pressure control. We will also support you in making some lifestyle changes, like diet and exercise, to help manage your diabetes better. Regular follow-up appointments will be important to keep track of your progress and prevent further complications.
#
# OpenAI GPT-5.2 Response to Prompt B:
# ------------------------------------------------------------
# Clinical Summary
# - Type 2 diabetes mellitus with poor glycaemic control: persistently elevated HbA1c and fasting blood glucose above recommended targets.
# - Early microvascular involvement suspected: intermittent paraesthesia in the feet and borderline microalbuminuria on recent testing.
# - Hypertension suboptimally controlled despite current therapy.
# - Current concerns: ongoing hyperglycaemia and inadequate BP control with early diabetic complication markers; priorities include intensification of glycaemic/BP management, reinforcement of lifestyle modifications, and close follow-up to limit progression.
#
# Patient Explanation
# - Your type 2 diabetes is not as well controlled as we want right now. This shows up in your longer-term sugar test (HbA1c) and your fasting blood sugar readings, which have been staying higher than the usual targets.
# - We’re also seeing some early signs that high blood sugar may be starting to affect small blood vessels and nerves: you’ve had on-and-off tingling or numbness in your feet (paraesthesia), and your urine test showed a borderline amount of protein (microalbuminuria), which can be an early marker of kidney stress.
# - Your blood pressure is also still running higher than we’d like, even with the treatment you’re currently on.
# - The main focus now is tightening control of your blood sugar and blood pressure and making sure we keep a close eye on things, because this is how we reduce the chance of these early changes getting worse over time.
#
# Anthropic Claude Sonnet-4.5 Response to Prompt B:
# ------------------------------------------------------------
# **Clinical Summary**
#
# Patient with poorly controlled type 2 diabetes mellitus, demonstrated by persistently elevated HbA1c and fasting glucose above target range. Early microvascular complications are emerging, including intermittent peripheral paraesthesia and borderline microalbuminuria on recent urinalysis. Blood pressure control remains inadequate on current antihypertensive regimen. Immediate management priorities include intensification of both glycaemic control and antihypertensive therapy, reinforcement of lifestyle modification strategies, and establishment of close interval follow-up to prevent progression of diabetic microvascular disease.
#
# ---
#
# **Patient Explanation**
#
# Your diabetes isn't as well controlled as we'd like it to be right now. The blood sugar tests we've been tracking show levels that are higher than our target, which means your current treatment plan needs to be adjusted. We're also seeing some early signs that high blood sugar may be affecting the small blood vessels in your body—you've mentioned tingling in your feet, and we found small amounts of protein in your urine that shouldn't be there. Your blood pressure is also running higher than we want, even with your current medication.
#
# The good news is that we've caught these changes early, and we can take action now to prevent them from getting worse. We need to strengthen your diabetes and blood pressure medications, and we'll work together on diet and activity changes that can help. We'll also see you more frequently over the coming weeks to make sure the new plan is working well for you.
